# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()
API_KEY=os.getenv("CLAUDE_API_KEY")

client = Anthropic(api_key=API_KEY)
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }
    if thinking:
        params['thinking'] = {
            'type': 'enabled',
            'budget_tokens': thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write one paragraph explaining the concepts of recursion")

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CdiaEB7FoRFGAbgcH2XuH', container=None, content=[ThinkingBlock(signature='...', thinking='I need to explain recursion in one paragraph. Recursion is a fundamental concept in computer science and mathematics where a function calls itself to solve a problem. I should cover:\n1. Basic definition\n2. Key components (base case and recursive case)\n3. How it works\n4. Maybe a simple example or analogy\n5. Keep it clear and concise in one paragraph\n\nLet me write a comprehensive but accessible explanation.', type='thinking'), TextBlock(citations=None, text="Recursion is a programming technique where a function solves a problem by calling itself with modified inputs until it reaches a simple base case that can be solved directly. Think of it like looking into two mirrors facing each other—each reflection contains a smaller version of the same image. A recursive function has two essential components: the **base case**, which stops the recursion by providing a direct answer for the simplest version of the problem, and the **recursive case**, which breaks down the problem into smaller, similar subproblems. For example, calculating a factorial (5! = 5 × 4 × 3 × 2 × 1) can be expressed recursively: the factorial of n equals n multiplied by the factorial of (n-1), with the base case being that the factorial of 1 equals 1. While recursion can make code more elegant and easier to understand for problems with naturally recursive structures (like tree traversal or the Fibonacci sequence), it's important to ensure proper base cases exist to prevent infinite loops and to be mindful of memory usage, as each recursive call adds a new layer to the call stack.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=45, output_tokens=342, output_tokens_details=OutputTokensDetails(thinking_tokens=96), server_tool_use=None, service_tier='standard'))
